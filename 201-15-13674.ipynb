# %%
import pandas as pd

# %%
df = pd.read_csv("E:\Codes\Data Mining\Lab Task 1\car_evaluation.csv")
df.describe()
# Out:
#        vhigh vhigh.1     2   2.1 small   low  unacc
# count   1727    1727  1727  1727  1727  1727   1727
# unique     4       4     4     3     3     3      4
# top     high    high     3     4   med   med  unacc
# freq     432     432   432   576   576   576   1209

# %%
df.isnull().sum()
# Out:
# vhigh      0
# vhigh.1    0
# 2          0
# 2.1        0
# small      0
# low        0
# unacc      0
# dtype: int64

# %%
df["vhigh"] = df["vhigh"].replace({"vhigh": 4, "high": 3, "med": 2, "low": 1})
df["vhigh.1"] = df["vhigh.1"].replace({"vhigh": 4, "high": 3, "med": 2, "low": 1})
df["2"] = df["2"].replace("5more", 6)
df["2.1"] = df["2.1"].replace("more", 6)
df["small"] = df["small"].replace({"small": 0, "big": 2, "med":1})
df["low"] = df["low"].replace({"small": 1,"med":2, "big": 3, "high": 4, "low": 0})
df["unacc"] = df["unacc"].replace({"unacc": 0,"acc":1, "good": 2, "vgood": 3})

# %%
df
# Out:
#       vhigh  vhigh.1  2 2.1  small  low  unacc
# 0         4        4  2   2      0    2      0
# 1         4        4  2   2      0    4      0
# 2         4        4  2   2      1    0      0
# 3         4        4  2   2      1    2      0
# 4         4        4  2   2      1    4      0
# ...     ...      ... ..  ..    ...  ...    ...
# 1722      1        1  6   6      1    2      2
# 1723      1        1  6   6      1    4      3
# 1724      1        1  6   6      2    0      0
# 1725      1        1  6   6      2    2      2
# 1726      1        1  6   6      2    4      3
#
# [1727 rows x 7 columns]

# %%
feature = df["vhigh","vhigh.1" "2", "2.1", "small", "low"]
target = df["unacc"]

x = df[feature]
y = df[target]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\frahm\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\frahm\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\frahm\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
df
# Out:
#       vhigh  vhigh.1 Two TwoOne  small  low  unacc
# 0         4        4   2      2      0    2      0
# 1         4        4   2      2      0    4      0
# 2         4        4   2      2      1    0      0
# 3         4        4   2      2      1    2      0
# 4         4        4   2      2      1    4      0
# ...     ...      ...  ..    ...    ...  ...    ...
# 1722      1        1   6      6      1    2      2
# 1723      1        1   6      6      1    4      3
# 1724      1        1   6      6      2    0      0
# 1725      1        1   6      6      2    2      2
# 1726      1        1   6      6      2    4      3
#
# [1727 rows x 7 columns]
